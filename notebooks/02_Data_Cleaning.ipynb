# %% [markdown]
# # Step 2: Data Cleaning & Preprocessing
# This notebook cleans the raw data by handling outliers, correcting category mappings, fixing country anomalies, modeling profit based on category margins, and exporting to CSV.

# %%
import sys
import pandas as pd
sys.path.append('..')
from src.clean_data import clean_sales_data

# %% [markdown]
# ## Execute the Cleaning Pipeline
# This runs the cleaning functions and saves the output to `data/processed/cleaned_sales.csv`.

# %%
df_cleaned = clean_sales_data(
    raw_file_path="../data/raw/Amazon_Sales.xlsx",
    processed_file_path="../data/processed/cleaned_sales.csv"
)
# Out:
# Loading raw data from: ../data/raw/Amazon_Sales.xlsx...
# Successfully loaded raw data. Shape: (100000, 20)
# Checking for null values...
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64
# Removing 0 duplicate rows...
# Formatting order dates...
# Correcting product category assignments and extracting sub-categories...
# Standardizing Country field to 'United States'...
# Detecting and capping price outliers...
# Calculating COGS and Profit based on product categories...
# Saving cleaned dataset to: ../data/processed/cleaned_sales.csv...
# Data cleaning completed successfully.

# %% [markdown]
# ## Verification of Cleaned Dataset
# Check details after processing.

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  datetime64[ns]
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
# ...

# %%
print("Unique Categories:", df_cleaned['Category'].unique())
print("Unique Countries:", df_cleaned['Country'].unique())
print("Missing Values:", df_cleaned.isnull().sum().sum())
# Out:
# Unique Categories: ['Electronics' 'Clothing' 'Home & Kitchen' 'Toys & Games'
#  'Sports & Outdoors' 'Books']
# Unique Countries: ['United States']
# Missing Values: 0

# %% [markdown]
# ## Preview Cleaned Records
# Check first 3 rows of the processed dataset with the new `Profit`, `COGS`, and `Sub_Category` columns.

# %%
df_cleaned[['OrderID', 'ProductName', 'Category', 'Sub_Category', 'TotalAmount', 'COGS', 'Profit']].head(3)
# Out:
#       OrderID          ProductName     Category        Sub_Category  \
# 0  ORD0000001           Drone Mini  Electronics              Drones
# 1  ORD0000002           Microphone  Electronics               Audio
# 2  ORD0000003  Power Bank 20000mAh  Electronics  Mobile Accessories
#
#    TotalAmount      COGS   Profit
# 0       319.86  271.8045  47.9655
# 1       259.64  213.6645  25.1370
# 2       108.06   89.3265   5.2545
