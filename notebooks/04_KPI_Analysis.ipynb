# %% [markdown]
# # Step 4: Key Performance Indicators (KPIs)
# This notebook calculates global performance metrics for Amazon sales, order volume, and margins.

# %%
import sys
import pandas as pd
sys.path.append('..')
from src.analysis import calculate_kpis

# %% [markdown]
# ## Load Processed Dataset

# %%
df = pd.read_csv('../data/processed/cleaned_sales.csv')

# %% [markdown]
# ## Compute Primary KPIs

# %%
kpi = calculate_kpis(df)

print(f"1. Total Sales (Revenue): ${kpi['total_sales']:,.2f}")
print(f"2. Total Profit:            ${kpi['total_profit']:,.2f}")
print(f"3. Total Orders (Volume):    {kpi['total_orders']:,}")
print(f"4. Average Sale Amount:     ${kpi['avg_sales']:,.2f}")
print(f"5. Average Profit Amount:   ${kpi['avg_profit']:,.2f}")
print(f"6. Maximum Sale Amount:     ${kpi['max_sales']:,.2f}")
print(f"7. Minimum Sale Amount:     ${kpi['min_sales']:,.2f}")
print(f"8. Average Order Value:     ${kpi['avg_order_value']:,.2f}")
print(f"9. Net Profit Margin:       {kpi['profit_margin'] * 100:.2f}%")
# Out:
# 1. Total Sales (Revenue): $91,559,101.73
# 2. Total Profit:            $11,122,316.29
# 3. Total Orders (Volume):    100,000
# 4. Average Sale Amount:     $915.59
# 5. Average Profit Amount:   $111.22
# 6. Maximum Sale Amount:     $2,863.08
# 7. Minimum Sale Amount:     $4.27
# 8. Average Order Value:     $915.59
# 9. Net Profit Margin:       12.15%
